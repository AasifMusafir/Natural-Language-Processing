# %% [markdown]
# # N-GRAM
#
# N-gram is a contiguous sequence of 'N' items like words or characters from text or speech. The items can be letters, words or base pairs according to the application. The value of ’N’ determines the order of the N-gram. They are fundamental concept used in various NLP tasks such as language modeling, text classification, machine translation and more.
#
# **N-grams can be of various types based on the value of 'n':**
#
# **Unigrams (1-grams)** are single words
#
# **Bigrams (2-grams)** are pairs of consecutive words
#
# **Trigrams (3-grams)** are triplets of consecutive words

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()

#Data cleaning and preprocessing
import re
import nltk
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\aasif\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import pandas as pd

messages=pd.read_csv(r"C:\Users\aasif\Downloads\Streamlit\spamhamdata.csv",sep="\t",names=["label","message"])

# %%
corpus = []

for i in range(0,len(messages)):
    review = re.sub('[^a-zA-Z]', ' ', messages["message"][i])
    review = review.lower()
    review = review.split()
    corpus.append(review)
    review=[ps.stem(word) for word in review if word not in set(stopwords.words("english"))]
    review=" ".join(review)
    corpus.append(review)

# %%
#Creating Bag of Words(BoW) model
corpus_str = [' '.join(tokens) for tokens in corpus]
from sklearn.feature_extraction.text import CountVectorizer
cov=CountVectorizer(max_features=2500,lowercase=True,ngram_range=(1, 1)) #for binary BOW enable binary=True

# %%
X=cov.fit_transform(corpus_str).toarray()

# %%
cov.vocabulary_
# Out:
# {'go': 839,
#  'until': 2259,
#  'point': 1595,
#  'crazy': 468,
#  'available': 149,
#  'only': 1484,
#  'in': 1014,
#  'bugis': 283,
#  'great': 864,
#  'world': 2432,
#  'la': 1127,
#  'cine': 385,
#  'there': 2131,
#  'got': 855,
#  'wat': 2345,
#  'ok': 1472,
#  'lar': 1137,
#  'joking': 1086,
#  'wif': 2394,
#  'oni': 1482,
#  'free': 764,
#  'entry': 646,
#  'wkly': 2414,
#  'comp': 426,
#  'to': 2175,
#  'win': 2399,
#  'fa': 681,
#  'cup': 481,
#  'final': 718,
#  'tkts': 2171,
#  'st': 1985,
#  'may': 1279,
#  'text': 2110,
#  'receive': 1708,
#  'question': 1665,
#  'std': 2000,
#  'txt': 2231,
#  'rate': 1685,
#  'apply': 106,
#  'over': 1512,
#  'dun': 603,
#  'say': 1808,
#  'so': 1936,
#  'early': 609,
#  'already': 68,
#  'then': 2129,
#  'nah': 1396,
#  'don': 575,
#  'think': 2136,
#  'he': 917,
#  'goes': 842,
#  'usf': 2280,
#  'lives': 1192,
#  'around': 124,
#  'here': 930,
#  'though': 2146,
#  'freemsg': 766,
#  'hey': 931,
#  'darling': 501,
#  'it': 1058,
#  'been': 189,
#  'week': 2362,
#  'now': 1450,
#  'and': 82,
#  'no': 1434,
#  'word': 2426,
#  'back': 161,
#  'like': 1182,
#  'some': 1941,
#  'fun': 789,
#  'you': 2490,
#  'up': 2260,
#  'for': 750,
#  'still': 2002,
#  'tb': 2087,
#  'xxx': 2463,
#  'send': 1841,
#  'rcv': 1689,
#  'even': 656,
#  'my': 1393,
#  'brother': 273,
#  'is': 1050,
#  'not': 1446,
#  'speak': 1968,
#  'with': 2408,
#  'me': 1282,
#  'they': 2133,
#  'treat': 2209,
#  'as': 131,
#  'per': 1541,
#  'your': 2491,
#  'request': 1742,
#  'melle': 1299,
#  'oru': 1502,
#  'nurungu': 1457,
#  'vettam': 2299,
#  'has': 909,
#  'set': 1851,
#  'callertune': 302,
#  'all': 63,
#  'callers': 301,
#  'press': 1627,
#  'copy': 453,
#  'friends': 774,
#  'winner': 2402,
#  'valued': 2290,
#  'network': 1417,
#  'customer': 486,
#  'have': 913,
#  'selected': 1834,
#  'prize': 1635,
#  'reward': 1759,
#  'claim': 389,
#  'call': 298,
#  'code': 407,
#  'valid': 2287,
#  'hours': 971,
#  'had': 883,
#  'mobile': 1337,
#  'months': 1355,
#  'or': 1495,
#  'more': 1359,
#  'entitled': 645,
#  'update': 2261,
#  'the': 2124,
#  'latest': 1142,
#  'colour': 417,
#  'mobiles': 1338,
#  'camera': 308,
#  'co': 405,
#  'on': 1478,
#  'gonna': 847,
#  'be': 182,
#  'home': 954,
#  'soon': 1953,
#  'want': 2336,
#  'talk': 2081,
#  'about': 5,
#  'this': 2140,
#  'stuff': 2026,
#  'anymore': 94,
#  'tonight': 2189,
#  've': 2294,
#  'enough': 642,
#  'today': 2177,
#  'six': 1910,
#  'cash': 331,
#  'from': 780,
#  'pounds': 1614,
#  'cost': 456,
#  'day': 508,
#  'days': 509,
#  'reply': 1738,
#  'hl': 943,
#  'info': 1024,
#  'urgent': 2269,
#  'won': 2420,
#  'membership': 1302,
#  'our': 1507,
#  'www': 2454,
#  'net': 1415,
#  'pobox': 1592,
#  'ldnw': 1151,
#  'searching': 1820,
#  'right': 1762,
#  'words': 2427,
#  'thank': 2118,
#  'promise': 1645,
#  'wont': 2425,
#  'take': 2076,
#  'help': 928,
#  'will': 2397,
#  'wonderful': 2422,
#  'at': 142,
#  'times': 2166,
#  'date': 504,
#  'sunday': 2046,
#  'use': 2277,
#  'credit': 471,
#  'click': 396,
#  'wap': 2340,
#  'link': 1186,
#  'next': 1425,
#  'message': 1306,
#  'http': 980,
#  'com': 418,
#  'oh': 1471,
#  'watching': 2347,
#  'eh': 622,
#  'remember': 1731,
#  'how': 973,
#  'spell': 1972,
#  'his': 939,
#  'name': 1398,
#  'yes': 2479,
#  'did': 539,
#  'naughty': 1406,
#  'make': 1253,
#  'wet': 2376,
#  'fine': 721,
#  'if': 1003,
#  'that': 2122,
#  'way': 2350,
#  'feel': 701,
#  'its': 1060,
#  'england': 638,
#  'dont': 577,
#  'miss': 1324,
#  'team': 2094,
#  'news': 1424,
#  'ur': 2266,
#  'national': 1403,
#  'eg': 619,
#  'try': 2218,
#  'wales': 2326,
#  'wq': 2443,
#  'seriously': 1848,
#  'going': 844,
#  'ha': 882,
#  'pay': 1537,
#  'first': 725,
#  'when': 2380,
#  'da': 492,
#  'stock': 2003,
#  'comin': 422,
#  'aft': 34,
#  'finish': 723,
#  'lunch': 1236,
#  'str': 2015,
#  'down': 580,
#  'lor': 1213,
#  'ard': 114,
#  'smth': 1932,
#  'alright': 69,
#  'can': 310,
#  'meet': 1294,
#  'sooner': 1954,
#  'just': 1096,
#  'myself': 1394,
#  'eat': 613,
#  'really': 1702,
#  'hungry': 984,
#  'tho': 2144,
#  'sucks': 2039,
#  'mark': 1265,
#  'getting': 824,
#  'worried': 2433,
#  'knows': 1124,
#  'sick': 1889,
#  'turn': 2226,
#  'pizza': 1570,
#  'lol': 1203,
#  'always': 72,
#  'catch': 333,
#  'bus': 285,
#  'are': 115,
#  'frying': 782,
#  'an': 81,
#  'egg': 620,
#  'tea': 2091,
#  'eating': 616,
#  'mom': 1345,
#  'left': 1161,
#  'dinner': 552,
#  'do': 564,
#  'love': 1221,
#  'amp': 79,
#  'we': 2353,
#  're': 1692,
#  'car': 317,
#  'll': 1194,
#  'let': 1171,
#  'know': 1122,
#  'room': 1777,
#  'work': 2428,
#  'what': 2377,
#  'does': 567,
#  'wait': 2321,
#  'clear': 394,
#  'were': 2375,
#  'sure': 2058,
#  'being': 197,
#  'why': 2392,
#  'doesn': 568,
#  'live': 1191,
#  'us': 2275,
#  'yeah': 2473,
#  'was': 2342,
#  'out': 1508,
#  'she': 1861,
#  'child': 373,
#  'caught': 335,
#  'till': 2164,
#  'but': 287,
#  'doing': 573,
#  'too': 2191,
#  'cheers': 369,
#  'tell': 2100,
#  'anything': 97,
#  'of': 1464,
#  'quick': 1667,
#  'thanks': 2119,
#  'subscription': 2036,
#  'ringtone': 1764,
#  'uk': 2240,
#  'charged': 357,
#  'month': 1353,
#  'please': 1583,
#  'confirm': 438,
#  'by': 292,
#  'replying': 1739,
#  'yup': 2498,
#  'look': 1208,
#  'msg': 1375,
#  'again': 38,
#  'xuhui': 2461,
#  'learn': 1154,
#  'nd': 1407,
#  'her': 929,
#  'lesson': 1169,
#  'am': 74,
#  'oops': 1487,
#  'roommate': 1778,
#  'done': 576,
#  'see': 1828,
#  'letter': 1173,
#  'decide': 518,
#  'hello': 927,
#  'saturday': 1802,
#  'texting': 2112,
#  'decided': 519,
#  'tomo': 2185,
#  'trying': 2219,
#  'invite': 1041,
#  'pls': 1587,
#  'ahead': 45,
#  'wanted': 2337,
#  'weekend': 2363,
#  'abiola': 3,
#  'forget': 755,
#  'need': 1411,
#  'crave': 467,
#  'most': 1364,
#  'sweet': 2064,
#  'tried': 2211,
#  'sms': 1931,
#  'nokia': 1437,
#  'camcorder': 306,
#  'delivery': 529,
#  'tomorrow': 2186,
#  'who': 2389,
#  'seeing': 1829,
#  'hope': 961,
#  'man': 1259,
#  'well': 2370,
#  'lt': 1231,
#  'gt': 872,
#  'inches': 1016,
#  'calls': 304,
#  'messages': 1307,
#  'missed': 1325,
#  'didn': 540,
#  'get': 821,
#  'nigeria': 1429,
#  'hopefully': 962,
#  'tyler': 2236,
#  'could': 459,
#  'maybe': 1281,
#  'ask': 133,
#  'bit': 218,
#  'hospital': 966,
#  'kept': 1106,
#  'telling': 2101,
#  'weak': 2354,
#  'time': 2165,
#  'saw': 1807,
#  'class': 391,
#  'gram': 861,
#  'usually': 2283,
#  'half': 890,
#  'gets': 822,
#  'almost': 65,
#  'whole': 2390,
#  'second': 1824,
#  'fyi': 793,
#  'ride': 1761,
#  'morning': 1361,
#  'place': 1571,
#  'wow': 2441,
#  'never': 1421,
#  'embarassed': 629,
#  'thought': 2147,
#  'liked': 1183,
#  'since': 1898,
#  'best': 203,
#  'seemed': 1831,
#  'happy': 905,
#  'sorry': 1956,
#  'give': 832,
#  'ac': 8,
#  'new': 1422,
#  'red': 1715,
#  'play': 1578,
#  'ice': 996,
#  'correct': 454,
#  'end': 631,
#  'yesterday': 2481,
#  'find': 720,
#  'url': 2272,
#  'congrats': 440,
#  'year': 2474,
#  'special': 1969,
#  'cinema': 386,
#  'pass': 1532,
#  'yours': 2492,
#  'suprman': 2056,
#  'starwars': 1995,
#  'etc': 653,
#  'bx': 291,
#  'ip': 1046,
#  'pm': 1590,
#  'later': 1141,
#  'meeting': 1296,
#  'where': 2383,
#  'reached': 1694,
#  'series': 1846,
#  'pick': 1556,
#  'yourself': 2493,
#  'move': 1367,
#  'pain': 1521,
#  'good': 848,
#  'joke': 1084,
#  'girls': 830,
#  'situation': 1909,
#  'part': 1529,
#  'checking': 367,
#  'iq': 1048,
#  'took': 2192,
#  'forever': 753,
#  'come': 419,
#  'double': 579,
#  'check': 365,
#  'hair': 888,
#  'dresser': 586,
#  'said': 1794,
#  'wun': 2453,
#  'cut': 487,
#  'short': 1873,
#  'nice': 1427,
#  'pleased': 1584,
#  'advise': 30,
#  'following': 744,
#  'recent': 1711,
#  'review': 1758,
#  'mob': 1336,
#  'awarded': 155,
#  'bonus': 238,
#  'song': 1949,
#  'which': 2386,
#  'valuable': 2288,
#  'frnds': 778,
#  'rply': 1783,
#  'complimentary': 431,
#  'trip': 2212,
#  'dis': 557,
#  'ls': 1230,
#  'hear': 919,
#  'comes': 421,
#  'plane': 1574,
#  'wah': 2320,
#  'lucky': 1234,
#  'save': 1805,
#  'money': 1351,
#  'hee': 923,
#  'finished': 724,
#  'hi': 933,
#  'babe': 158,
#  'im': 1008,
#  'wanna': 2335,
#  'something': 1945,
#  'xx': 2462,
#  'waiting': 2323,
#  'machan': 1241,
#  'once': 1479,
#  'thats': 2123,
#  'cool': 452,
#  'gentleman': 817,
#  'dignity': 550,
#  'respect': 1745,
#  'very': 2298,
#  'much': 1383,
#  'shy': 1887,
#  'pa': 1515,
#  'after': 35,
#  'same': 1798,
#  'looking': 1211,
#  'job': 1080,
#  'ta': 2073,
#  'ah': 43,
#  'stop': 2008,
#  'urgnt': 2271,
#  'real': 1699,
#  'yo': 2486,
#  'tickets': 2161,
#  'one': 1480,
#  'used': 2278,
#  'started': 1992,
#  'requests': 1743,
#  'came': 307,
#  'bed': 187,
#  'coins': 409,
#  'gotta': 857,
#  'kano': 1100,
#  'il': 1006,
#  'download': 581,
#  'wen': 2372,
#  'stand': 1987,
#  'close': 399,
#  'another': 85,
#  'night': 1430,
#  'spent': 1975,
#  'late': 1140,
#  'afternoon': 36,
#  'means': 1286,
#  'haven': 914,
#  'any': 92,
#  'moro': 1362,
#  'sheets': 1862,
#  'smile': 1926,
#  'pleasure': 1585,
#  'trouble': 2213,
#  'rain': 1675,
#  'sum': 2043,
#  'hurts': 988,
#  'becoz': 186,
#  'someone': 1943,
#  'loves': 1226,
#  'smiling': 1928,
#  'service': 1849,
#  'representative': 1741,
#  'between': 206,
#  'guaranteed': 873,
#  'havent': 915,
#  'planning': 1576,
#  'buy': 288,
#  'show': 1881,
#  'collected': 413,
#  'simply': 1897,
#  'password': 1535,
#  'verify': 2296,
#  'fml': 741,
#  'po': 1591,
#  'box': 257,
#  'mk': 1329,
#  'movie': 1368,
#  'abt': 6,
#  'loads': 1196,
#  'wk': 2412,
#  'hols': 953,
#  'run': 1787,
#  'forgot': 756,
#  'appointment': 107,
#  'four': 760,
#  'shower': 1882,
#  'cause': 336,
#  'prob': 1637,
#  'coffee': 408,
#  'nothing': 1448,
#  'else': 625,
#  'okay': 1473,
#  'price': 1632,
#  'long': 1206,
#  'legal': 1162,
#  'them': 2127,
#  'ave': 150,
#  'gone': 846,
#  'driving': 592,
#  'test': 2109,
#  'yet': 2482,
#  'mean': 1284,
#  'guess': 876,
#  'gave': 807,
#  'boston': 249,
#  'men': 1303,
#  'changed': 352,
#  'search': 1819,
#  'nyc': 1461,
#  'cuz': 490,
#  'page': 1518,
#  'says': 1810,
#  'umma': 2241,
#  'life': 1178,
#  'vava': 2293,
#  'lot': 1218,
#  'dear': 513,
#  'wishes': 2405,
#  'birthday': 216,
#  'making': 1255,
#  'truly': 2215,
#  'aight': 47,
#  'hit': 941,
#  'would': 2439,
#  'address': 24,
#  'considering': 444,
#  'computer': 432,
#  'isn': 1054,
#  'old': 1475,
#  'people': 1540,
#  'better': 205,
#  'jokes': 1085,
#  'worry': 2435,
#  'busy': 286,
#  'research': 1744,
#  'cos': 455,
#  'things': 2135,
#  'scared': 1811,
#  'mah': 1248,
#  'contact': 445,
#  'last': 1139,
#  'weekends': 2364,
#  'draw': 582,
#  'shows': 1884,
#  'hrs': 979,
#  'ppm': 1618,
#  'wa': 2319,
#  'anyway': 99,
#  'juz': 1097,
#  'tt': 2222,
#  'eatin': 615,
#  'weight': 2367,
#  'haha': 885,
#  'anythin': 96,
#  'happened': 901,
#  'entered': 644,
#  'cabin': 294,
#  'boss': 248,
#  'felt': 705,
#  'askd': 134,
#  'invited': 1042,
#  'apartment': 102,
#  'went': 2373,
#  'specially': 1970,
#  'holiday': 951,
#  'flights': 737,
#  'inc': 1015,
#  'operator': 1489,
#  'min': 1316,
#  'must': 1391,
#  'friday': 772,
#  'needed': 1412,
#  'hmm': 944,
#  'uncle': 2244,
#  'informed': 1027,
#  'paying': 1538,
#  'school': 1814,
#  'directly': 555,
#  'food': 746,
#  'private': 1634,
#  'account': 13,
#  'statement': 1996,
#  'unredeemed': 2255,
#  'points': 1596,
#  'identifier': 1000,
#  'expires': 677,
#  'caller': 300,
#  'landline': 1134,
#  'todays': 2178,
#  'voda': 2311,
#  'numbers': 1456,
#  'ending': 633,
#  'award': 154,
#  'match': 1271,
#  'quoting': 1672,
#  'standard': 1988,
#  'rates': 1686,
#  'app': 104,
#  'mu': 1382,
#  'buying': 289,
#  'yetunde': 2483,
#  'hasn': 910,
#  'sent': 1844,
#  'bother': 251,
#  'sending': 1842,
#  'shouldn': 1879,
#  'apologise': 103,
#  'girl': 828,
#  'del': 525,
#  'bak': 165,
#  'answer': 88,
#  'sunshine': 2048,
#  'quiz': 1670,
#  'top': 2193,
#  'sony': 1951,
#  'dvd': 606,
#  'player': 1580,
#  'country': 461,
#  'ansr': 87,
#  'sp': 1965,
#  'tyrone': 2238,
#  'laid': 1132,
#  'dogging': 571,
#  'locations': 1199,
#  'direct': 554,
#  'join': 1082,
#  'largest': 1138,
#  'bt': 277,
#  'txting': 2234,
#  'nt': 1451,
#  'ec': 617,
#  'haf': 884,
#  'yijue': 2484,
#  'him': 936,
#  'rooms': 1779,
#  'befor': 191,
#  'activities': 18,
#  'msgs': 1377,
#  'chat': 360,
#  'hardcore': 907,
#  'services': 1850,
#  'age': 40,
#  'yr': 2494,
#  'lazy': 1148,
#  'type': 2237,
#  'lect': 1159,
#  'sir': 1903,
#  'mail': 1250,
#  'swt': 2069,
#  'tired': 2168,
#  'little': 1190,
#  'lovable': 1220,
#  'persons': 1547,
#  'coz': 465,
#  'those': 2145,
#  'biggest': 212,
#  'their': 2126,
#  'gud': 874,
#  'ni': 1426,
#  'open': 1488,
#  'ya': 2468,
#  'whats': 2379,
#  'taking': 2080,
#  'replied': 1737,
#  'sexy': 1855,
#  'local': 1198,
#  'luv': 1237,
#  'netcollex': 1416,
#  'ltd': 1232,
#  'begin': 193,
#  'qatar': 1660,
#  'pray': 1622,
#  'hard': 906,
#  'deleted': 526,
#  'wine': 2401,
#  'thk': 2141,
#  'floor': 739,
#  'shirt': 1866,
#  'sometimes': 1947,
#  'dream': 583,
#  'without': 2410,
#  'joy': 1089,
#  'lots': 1219,
#  'tv': 2228,
#  'become': 185,
#  'leaving': 1158,
#  'house': 972,
#  'interview': 1038,
#  'boy': 258,
#  'missing': 1326,
#  'years': 2475,
#  'arrange': 125,
#  'keep': 1104,
#  'safe': 1793,
#  'because': 184,
#  'everyone': 661,
#  'parents': 1524,
#  'hand': 893,
#  'each': 607,
#  'spend': 1973,
#  'inviting': 1043,
#  'friend': 773,
#  'frnd': 777,
#  'order': 1498,
#  'should': 1878,
#  'content': 447,
#  'goto': 856,
#  'internet': 1037,
#  'menu': 1304,
#  'wit': 2407,
#  'escape': 649,
#  'fancy': 687,
#  'needs': 1413,
#  'completely': 430,
#  'also': 71,
#  'waste': 2344,
#  'bank': 167,
#  'hmmm': 945,
#  'hop': 960,
#  'muz': 1392,
#  'discuss': 559,
#  'liao': 1175,
#  'coming': 423,
#  'bloody': 229,
#  'hell': 925,
#  'cant': 315,
#  'believe': 198,
#  'mr': 1371,
#  'ill': 1007,
#  'spanish': 1967,
#  'bath': 172,
#  'carlos': 326,
#  'mall': 1258,
#  'turns': 2227,
#  'staying': 1999,
#  'til': 2163,
#  'smoke': 1929,
#  'worth': 2437,
#  'doesnt': 569,
#  'log': 1200,
#  'spoke': 1978,
#  'maneesha': 1262,
#  'satisfied': 1801,
#  'experience': 676,
#  'toll': 2182,
#  'offer': 1466,
#  'especially': 650,
#  'studying': 2025,
#  'anyways': 100,
#  'gr': 859,
#  'trust': 2216,
#  'guys': 880,
#  'bye': 293,
#  'working': 2430,
#  'towards': 2202,
#  'mummy': 1385,
#  'boytoy': 260,
#  'awesome': 157,
#  'minute': 1320,
#  'freephone': 767,
#  'xmas': 2460,
#  'radio': 1674,
#  'jus': 1095,
#  'bathe': 173,
#  'sis': 1904,
#  'using': 2281,
#  'unique': 2251,
#  'th': 2115,
#  'joined': 1083,
#  'touch': 2198,
#  'deal': 512,
#  'personal': 1545,
#  'finally': 719,
#  'course': 463,
#  'itself': 1061,
#  'however': 974,
#  'suggest': 2041,
#  'able': 4,
#  'every': 659,
#  'settled': 1853,
#  'mrng': 1372,
#  'hav': 912,
#  'story': 2014,
#  'dead': 511,
#  'tmr': 2173,
#  'orchard': 1497,
#  'mrt': 1373,
#  'kate': 1102,
#  'evening': 657,
#  'found': 759,
#  'bucks': 279,
#  'darlin': 500,
#  'ive': 1062,
#  'college': 416,
#  'successfully': 2038,
#  'decimal': 520,
#  'balance': 166,
#  'rs': 1784,
#  'transaction': 2207,
#  'id': 997,
#  'goodmorning': 849,
#  'sleeping': 1920,
#  'ga': 794,
#  'dat': 503,
#  'oso': 1503,
#  'cannot': 314,
#  'oredi': 1500,
#  'straight': 2016,
#  'connection': 443,
#  'before': 192,
#  'bill': 213,
#  'both': 250,
#  'shoot': 1870,
#  'big': 211,
#  'ready': 1698,
#  'break': 262,
#  'semester': 1839,
#  'study': 2024,
#  'noe': 1436,
#  'leh': 1164,
#  'sounds': 1963,
#  'slept': 1921,
#  'past': 1536,
#  'few': 708,
#  'nights': 1431,
#  'easy': 612,
#  'sen': 1840,
#  'exam': 667,
#  'march': 1264,
#  'atm': 145,
#  'register': 1722,
#  'called': 299,
#  'important': 1012,
#  'files': 714,
#  'system': 2072,
#  'shop': 1871,
#  'happen': 899,
#  'romantic': 1775,
#  'nite': 1433,
#  'collect': 412,
#  'tc': 2088,
#  'biz': 220,
#  'optout': 1494,
#  'gbp': 810,
#  'mtmsg': 1380,
#  'appreciate': 108,
#  'partner': 1530,
#  'career': 321,
#  'off': 1465,
#  'start': 1991,
#  'followed': 743,
#  'sign': 1893,
#  'company': 427,
#  'than': 2116,
#  'bcoz': 179,
#  'teaches': 2093,
#  'lessons': 1170,
#  'walk': 2327,
#  'cross': 474,
#  'road': 1768,
#  'side': 1890,
#  'street': 2018,
#  'battery': 175,
#  'died': 543,
#  'flirt': 738,
#  'sam': 1797,
#  'recd': 1706,
#  'closer': 401,
#  'wil': 2396,
#  'reach': 1693,
#  'theory': 2130,
#  'argument': 120,
#  'wins': 2403,
#  'person': 1544,
#  'argue': 119,
#  'kick': 1111,
#  'secret': 1826,
#  'admirer': 25,
#  'reveal': 1756,
#  'thinks': 2139,
#  'tomarrow': 2184,
#  'laptop': 1136,
#  'case': 330,
#  'tel': 2099,
#  'meant': 1287,
#  'told': 2181,
#  'into': 1039,
#  'face': 682,
#  'watch': 2346,
#  'fr': 761,
#  'thanx': 2121,
#  'everything': 662,
#  'touched': 2199,
#  'website': 2358,
#  'asked': 135,
#  'kallis': 1099,
#  'bat': 171,
#  'didnt': 541,
#  'goodnight': 850,
#  'fix': 729,
#  'wake': 2324,
#  'dearly': 515,
#  'sleep': 1919,
#  'congratulations': 441,
#  'cd': 339,
#  'vouchers': 2317,
#  'gift': 826,
#  'music': 1390,
#  'tncs': 2174,
#  'ldew': 1149,
#  'ppmx': 1619,
#  'ranjith': 1684,
#  'cal': 297,
#  'hold': 948,
#  'bcums': 180,
#  'angry': 83,
#  'wid': 2393,
#  'dnt': 563,
#  'childish': 374,
#  'true': 2214,
#  'showing': 1883,
#  'deep': 522,
#  ...}

# %%
#Creating Bag of Words(BoW) model
corpus_str = [' '.join(tokens) for tokens in corpus]
from sklearn.feature_extraction.text import CountVectorizer
cov=CountVectorizer(max_features=2500,lowercase=True,ngram_range=(2, 2)) #for binary BOW enable binary=True

X=cov.fit_transform(corpus_str).toarray()

# %%
cov.vocabulary_ #(for (2,2) bigram)
# Out:
# {'free entry': 539,
#  'entry in': 486,
#  'to win': 2033,
#  'to to': 2028,
#  'to receive': 2012,
#  'std txt': 1781,
#  'txt rate': 2063,
#  'rate apply': 1547,
#  'so early': 1711,
#  'don think': 461,
#  'hey there': 734,
#  'now and': 1351,
#  'you up': 2459,
#  'up for': 2078,
#  'for it': 515,
#  'it still': 976,
#  'to send': 2015,
#  'send to': 1645,
#  'even my': 490,
#  'my brother': 1258,
#  'is not': 924,
#  'like to': 1087,
#  'with me': 2329,
#  'me like': 1178,
#  'as per': 111,
#  'per your': 1486,
#  'your request': 2494,
#  'has been': 671,
#  'been set': 193,
#  'set as': 1660,
#  'as your': 117,
#  'your callertune': 2475,
#  'callertune for': 295,
#  'for all': 506,
#  'all callers': 17,
#  'callers press': 294,
#  'press to': 1526,
#  'to copy': 1970,
#  'copy your': 397,
#  'your friends': 2481,
#  'friends callertune': 549,
#  'as valued': 114,
#  'customer you': 415,
#  'you have': 2413,
#  'have been': 679,
#  'been selected': 192,
#  'selected to': 1630,
#  'to claim': 1966,
#  'claim call': 353,
#  'call claim': 267,
#  'claim code': 354,
#  'valid hours': 2119,
#  'hours only': 773,
#  'had your': 657,
#  'your mobile': 2486,
#  'entitled to': 485,
#  'to update': 2030,
#  'update to': 2091,
#  'to the': 2024,
#  'the latest': 1869,
#  'latest colour': 1059,
#  'for free': 512,
#  'free call': 537,
#  'call the': 288,
#  'the mobile': 1874,
#  'mobile update': 1236,
#  'update co': 2089,
#  'co free': 360,
#  'free on': 543,
#  'gonna be': 613,
#  'be home': 175,
#  'and don': 49,
#  'don want': 462,
#  'want to': 2169,
#  'to talk': 2022,
#  'about this': 7,
#  'win cash': 2312,
#  'and send': 68,
#  'reply hl': 1580,
#  'hl info': 752,
#  'have won': 697,
#  'week free': 2221,
#  'in our': 865,
#  'txt the': 2065,
#  'the word': 1900,
#  'to no': 2002,
#  've been': 2121,
#  'for the': 528,
#  'the right': 1889,
#  'thank you': 1827,
#  'you for': 2401,
#  'take your': 1807,
#  'and will': 78,
#  'at all': 124,
#  'to use': 2032,
#  'use your': 2116,
#  'in the': 873,
#  'the next': 1880,
#  'did he': 431,
#  'if that': 819,
#  'that the': 1843,
#  'the way': 1896,
#  'dont miss': 467,
#  'to eg': 1974,
#  'is that': 932,
#  'how you': 792,
#  'going to': 612,
#  'ha ha': 654,
#  'when is': 2262,
#  'my lunch': 1275,
#  'then go': 1908,
#  'can meet': 319,
#  'meet up': 1204,
#  'up with': 2088,
#  'with you': 2337,
#  'to eat': 1973,
#  'he knows': 706,
#  'did you': 435,
#  'the bus': 1859,
#  'are you': 105,
#  'you make': 2426,
#  'your mom': 2487,
#  'do you': 452,
#  'you feel': 2400,
#  'my love': 1274,
#  'we re': 2211,
#  'll let': 1106,
#  'let you': 1076,
#  'you know': 2419,
#  'know if': 1035,
#  'that what': 1848,
#  'does it': 454,
#  'feel like': 497,
#  'all that': 23,
#  'you not': 2433,
#  'not sure': 1343,
#  'about me': 3,
#  'that why': 1849,
#  'to live': 1994,
#  'live with': 1094,
#  'he got': 703,
#  'in at': 838,
#  'and was': 75,
#  'out and': 1465,
#  'and she': 69,
#  'and he': 53,
#  'up in': 2080,
#  'in that': 872,
#  'but we': 249,
#  'tell me': 1812,
#  'about you': 9,
#  'with the': 2334,
#  'of all': 1376,
#  'you just': 2418,
#  'thanks for': 1828,
#  'for your': 531,
#  'mobile will': 1238,
#  'will be': 2295,
#  'be charged': 170,
#  'by replying': 257,
#  'yes or': 2368,
#  'or no': 1447,
#  'if you': 825,
#  'no you': 1326,
#  'you will': 2466,
#  'will not': 2305,
#  'not be': 1337,
#  'go home': 601,
#  'look at': 1121,
#  'at the': 136,
#  'is at': 894,
#  'know when': 1040,
#  'when my': 2264,
#  'my roommate': 1284,
#  'see the': 1623,
#  'on my': 1416,
#  'my car': 1260,
#  'anything lor': 89,
#  'you and': 2375,
#  'and how': 54,
#  'how did': 778,
#  'was just': 2177,
#  'to see': 2014,
#  'see if': 1618,
#  'decided to': 425,
#  'to do': 1971,
#  'do anything': 440,
#  'not that': 1344,
#  'trying to': 2057,
#  'just wanted': 1024,
#  'wanted to': 2171,
#  'to be': 1959,
#  'be sure': 183,
#  'do have': 441,
#  'have great': 683,
#  'to tell': 2023,
#  'tell you': 1815,
#  'you want': 2462,
#  'want you': 2170,
#  'you need': 2432,
#  'need you': 1299,
#  'you crave': 2391,
#  'crave you': 405,
#  'you but': 2384,
#  'most of': 1244,
#  'love you': 1135,
#  'you my': 2431,
#  'my sweet': 1288,
#  'we tried': 2215,
#  'tried to': 2054,
#  'to call': 1963,
#  'call you': 291,
#  'you re': 2440,
#  're your': 1559,
#  'your reply': 2493,
#  'reply to': 1583,
#  'to our': 2006,
#  'nokia mobile': 1328,
#  'mobile free': 1231,
#  'free camcorder': 538,
#  'please call': 1502,
#  'call now': 282,
#  'for delivery': 509,
#  'delivery tomorrow': 428,
#  'hope you': 769,
#  'you like': 2422,
#  'lt gt': 1137,
#  'you get': 2403,
#  'in nigeria': 861,
#  'going on': 610,
#  'can do': 309,
#  'do it': 442,
#  'it could': 953,
#  'don know': 459,
#  'know how': 1034,
#  'to go': 1981,
#  'go to': 605,
#  'what you': 2253,
#  'first time': 505,
#  'time you': 1952,
#  'me in': 1175,
#  'in class': 846,
#  'like lt': 1083,
#  'for lt': 516,
#  'but he': 232,
#  'that you': 1852,
#  'you were': 2463,
#  'thought you': 1946,
#  'the best': 1857,
#  'and you': 79,
#  'you always': 2374,
#  'about the': 6,
#  'don have': 458,
#  'to give': 1980,
#  'your room': 2496,
#  'was so': 2181,
#  'sms ac': 1702,
#  'the new': 1879,
#  'and the': 73,
#  'know what': 1039,
#  'find out': 504,
#  'is yours': 945,
#  'yours call': 2499,
#  'etc all': 488,
#  'all free': 19,
#  'bx ip': 253,
#  'ip we': 890,
#  'we pm': 2210,
#  'miss out': 1222,
#  'sorry ll': 1755,
#  'll call': 1097,
#  'call later': 278,
#  'later in': 1056,
#  'in meeting': 857,
#  'where you': 2278,
#  'out of': 1469,
#  'have to': 695,
#  'to pick': 2008,
#  'pick up': 1496,
#  'on your': 1428,
#  'way home': 2190,
#  'can even': 310,
#  'pain is': 1478,
#  'part of': 1480,
#  'it ok': 971,
#  'ok if': 1402,
#  'come by': 376,
#  'he said': 709,
#  'pleased to': 1504,
#  'you that': 2451,
#  'of your': 1395,
#  'your mob': 2485,
#  'you are': 2376,
#  'are awarded': 94,
#  'awarded with': 151,
#  'with bonus': 2324,
#  'prize call': 1532,
#  'today is': 2043,
#  'for me': 517,
#  'me send': 1186,
#  'send this': 1644,
#  'this to': 1940,
#  'to all': 1955,
#  'all ur': 26,
#  'ur awarded': 2092,
#  'trip to': 2055,
#  'or to': 1453,
#  'dis to': 438,
#  'you hear': 2414,
#  'with all': 2323,
#  'all of': 22,
#  'on this': 1423,
#  'this month': 1935,
#  'where are': 2272,
#  'hi babe': 738,
#  'at home': 127,
#  'home now': 764,
#  'wanna do': 2164,
#  'you how': 2415,
#  'can call': 307,
#  'call me': 279,
#  'me now': 1182,
#  'am waiting': 36,
#  'you free': 2402,
#  'thats cool': 1853,
#  'treat you': 2053,
#  'you with': 2467,
#  'like you': 1088,
#  'much but': 1250,
#  'but am': 226,
#  'gt or': 643,
#  'or what': 1455,
#  'its not': 993,
#  'the same': 1890,
#  'looking for': 1122,
#  'how much': 786,
#  'you call': 2385,
#  'just now': 1016,
#  'am on': 34,
#  'on the': 1422,
#  'way to': 2193,
#  'to home': 1987,
#  'hi hi': 741,
#  'be in': 176,
#  'the place': 1888,
#  'of that': 1387,
#  'you later': 2421,
#  'one more': 1431,
#  'all my': 20,
#  'to make': 1996,
#  'make it': 1147,
#  'it but': 950,
#  'came back': 297,
#  'back in': 160,
#  'in bed': 839,
#  'cash in': 340,
#  'up to': 2085,
#  'to it': 1989,
#  'wen ur': 2235,
#  'you ll': 2423,
#  'is it': 911,
#  'if we': 824,
#  'and that': 72,
#  'that means': 1837,
#  'any of': 85,
#  'smile in': 1696,
#  'smile when': 1699,
#  'call our': 286,
#  'our customer': 1458,
#  'customer service': 413,
#  'service representative': 1658,
#  'representative on': 1586,
#  'on between': 1410,
#  'between am': 206,
#  'am pm': 35,
#  'pm as': 1513,
#  'as you': 116,
#  'won guaranteed': 2345,
#  'guaranteed cash': 647,
#  'cash or': 341,
#  'or prize': 1448,
#  'planning to': 1500,
#  'to buy': 1962,
#  'your free': 2480,
#  'free ringtone': 544,
#  'is waiting': 941,
#  'text the': 1822,
#  'po box': 1516,
#  'wat abt': 2186,
#  'when we': 2268,
#  'we have': 2204,
#  'loads of': 1112,
#  'to pay': 2007,
#  'bit of': 210,
#  'need to': 1298,
#  'to get': 1979,
#  'get home': 569,
#  'text me': 1819,
#  'to say': 2013,
#  'long as': 1119,
#  'can pick': 323,
#  'them up': 1905,
#  'and have': 52,
#  'have not': 690,
#  'do that': 449,
#  'up on': 2082,
#  'my life': 1273,
#  'life and': 1077,
#  'my birthday': 1256,
#  'aight ll': 16,
#  'up when': 2087,
#  'when get': 2260,
#  'get some': 576,
#  'my mom': 1276,
#  'the one': 1883,
#  'to play': 2009,
#  'what is': 2245,
#  'is the': 933,
#  'of the': 1388,
#  'going for': 608,
#  'for dinner': 511,
#  'not too': 1346,
#  'we are': 2196,
#  'are trying': 101,
#  'to contact': 1969,
#  'contact you': 395,
#  'you last': 2420,
#  'last weekends': 1054,
#  'weekends draw': 2226,
#  'draw shows': 472,
#  'shows that': 1683,
#  'you won': 2468,
#  'won prize': 2347,
#  'prize guaranteed': 1534,
#  'guaranteed call': 646,
#  'code valid': 364,
#  'valid hrs': 2120,
#  'hrs only': 796,
#  'only ppm': 1437,
#  'too much': 2052,
#  'as entered': 108,
#  'entered my': 484,
#  'my cabin': 1259,
#  'cabin my': 262,
#  'my pa': 1280,
#  'pa said': 1477,
#  'said happy': 1602,
#  'happy day': 665,
#  'day boss': 418,
#  'boss felt': 215,
#  'felt special': 500,
#  'special she': 1766,
#  'she askd': 1663,
#  'askd me': 122,
#  'me lunch': 1179,
#  'lunch after': 1141,
#  'after lunch': 13,
#  'lunch she': 1142,
#  'she invited': 1668,
#  'invited me': 887,
#  'me to': 1194,
#  'to her': 1985,
#  'her apartment': 726,
#  'apartment we': 92,
#  'we went': 2217,
#  'went there': 2237,
#  'are winner': 104,
#  'been specially': 194,
#  'specially selected': 1768,
#  'selected receive': 1629,
#  'or holiday': 1445,
#  'holiday flights': 757,
#  'inc speak': 883,
#  'speak to': 1763,
#  'live operator': 1093,
#  'me that': 1191,
#  'that he': 1833,
#  'so pls': 1725,
#  'private your': 1531,
#  'your account': 2471,
#  'account statement': 10,
#  'statement for': 1779,
#  'for shows': 525,
#  'shows unredeemed': 1685,
#  'call identifier': 275,
#  'identifier code': 801,
#  'code expires': 362,
#  'urgent your': 2113,
#  'mobile no': 1233,
#  'no was': 1325,
#  'was awarded': 2174,
#  'awarded bonus': 147,
#  'bonus caller': 214,
#  'caller prize': 293,
#  'prize on': 1535,
#  'this is': 1933,
#  'is our': 927,
#  'our final': 1460,
#  'try to': 2056,
#  'call from': 272,
#  'from landline': 554,
#  'is my': 921,
#  'my new': 1278,
#  'todays voda': 2045,
#  'voda numbers': 2142,
#  'numbers ending': 1375,
#  'are selected': 99,
#  'receive award': 1570,
#  'award if': 146,
#  'have match': 686,
#  'match please': 1156,
#  'call quoting': 287,
#  'quoting claim': 1545,
#  'code standard': 363,
#  'standard rates': 1775,
#  'rates app': 1549,
#  'am going': 30,
#  'only at': 1434,
#  'wat time': 2188,
#  'will do': 2299,
#  'so that': 1727,
#  'just sent': 1020,
#  'not to': 1345,
#  'so its': 1716,
#  'you dont': 2397,
#  'dont have': 465,
#  'on you': 1427,
#  'you in': 2417,
#  'the first': 1864,
#  'for that': 527,
#  'you there': 2453,
#  'there in': 1917,
#  'in room': 867,
#  'long time': 1120,
#  'give me': 593,
#  'me call': 1169,
#  'will call': 2296,
#  'sunshine quiz': 1798,
#  'quiz wkly': 1544,
#  'win top': 2317,
#  'sony dvd': 1750,
#  'if know': 813,
#  'which country': 2280,
#  'is in': 909,
#  'sp tyrone': 1761,
#  'want real': 2168,
#  'locations sent': 1113,
#  'sent direct': 1647,
#  'ur mob': 2102,
#  'join the': 1003,
#  'the uk': 1895,
#  'largest dogging': 1050,
#  'he is': 705,
#  'is there': 934,
#  'call and': 264,
#  'meet him': 1202,
#  'no no': 1318,
#  'will check': 2297,
#  'from the': 558,
#  'if get': 808,
#  'me when': 1197,
#  'when you': 2270,
#  're on': 1557,
#  'waiting for': 2154,
#  'tired of': 1953,
#  'in their': 874,
#  'gud ni': 651,
#  'know you': 1043,
#  'can you': 330,
#  'you pls': 2439,
#  'see ya': 1625,
#  'whats the': 2256,
#  'who is': 2283,
#  'is taking': 931,
#  'to my': 2000,
#  'to hear': 1984,
#  'hear from': 713,
#  'per msg': 1484,
#  'reply stop': 1582,
#  'stop to': 1794,
#  'to end': 1975,
#  'got job': 626,
#  'job in': 1001,
#  'no need': 1317,
#  'of my': 1386,
#  'my world': 1292,
#  'time of': 1949,
#  'of joy': 1381,
#  'lots of': 1127,
#  'll see': 1108,
#  'and when': 77,
#  'is done': 899,
#  'you at': 2379,
#  'at work': 139,
#  'my house': 1271,
#  'hello my': 720,
#  'what are': 2240,
#  'you doing': 2395,
#  'get to': 581,
#  'you you': 2470,
#  'you happy': 2412,
#  'you being': 2382,
#  'being good': 200,
#  'you think': 2454,
#  'think of': 1929,
#  'of me': 1384,
#  'you missing': 2429,
#  'missing me': 1225,
#  'have new': 687,
#  'new years': 1307,
#  'for you': 530,
#  'you please': 2438,
#  'now to': 1365,
#  'receive cash': 1571,
#  'and miss': 63,
#  'miss you': 1223,
#  'you already': 2373,
#  'see you': 1626,
#  'for my': 520,
#  'my parents': 1281,
#  'new job': 1303,
#  'in love': 854,
#  'make me': 1148,
#  'me so': 1188,
#  'is inviting': 910,
#  'inviting you': 889,
#  'you to': 2456,
#  'be her': 173,
#  'her friend': 728,
#  'friend reply': 548,
#  'reply yes': 1585,
#  'no see': 1323,
#  'see her': 1616,
#  'her www': 730,
#  'www sms': 2360,
#  'stop send': 1791,
#  'send stop': 1641,
#  'stop frnd': 1789,
#  'frnd to': 551,
#  'is on': 926,
#  'do not': 447,
#  'on ur': 1426,
#  'ur mobile': 2103,
#  'urgent we': 2112,
#  'which is': 2281,
#  'time to': 1950,
#  'can go': 314,
#  'call to': 289,
#  'what time': 2248,
#  'you coming': 2389,
#  'now have': 1355,
#  'have good': 680,
#  'let me': 1075,
#  'me know': 1176,
#  'you ve': 2460,
#  've got': 2122,
#  'got the': 629,
#  'the money': 1875,
#  'can make': 318,
#  'make the': 1150,
#  'the call': 1860,
#  'my friends': 1267,
#  'the whole': 1899,
#  'be back': 168,
#  'if she': 818,
#  'so can': 1707,
#  'can have': 315,
#  'spoke to': 1770,
#  'to know': 1992,
#  'with yes': 2336,
#  'offer of': 1396,
#  'am in': 31,
#  'in need': 860,
#  'when the': 2266,
#  'the end': 1863,
#  'end of': 480,
#  'and it': 57,
#  'have gr': 682,
#  'lol no': 1117,
#  'will you': 2310,
#  'you guys': 2410,
#  'where my': 2275,
#  'my boytoy': 1257,
#  'does he': 453,
#  'miss me': 1221,
#  'haha awesome': 658,
#  'be there': 185,
#  'in minute': 858,
#  'have you': 698,
#  'you got': 2408,
#  'if not': 816,
#  'will get': 2300,
#  'get it': 571,
#  'it now': 969,
#  'reached home': 1562,
#  'but my': 238,
#  'my sis': 1285,
#  'co uk': 361,
#  'keep in': 1025,
#  'in touch': 877,
#  'to me': 1998,
#  'me you': 1198,
#  'it will': 984,
#  'someone that': 1746,
#  'that will': 1850,
#  'be able': 165,
#  'able to': 0,
#  'how are': 776,
#  'gr day': 631,
#  'gud mrng': 650,
#  'hav nice': 676,
#  'nice day': 1309,
#  'that persons': 1841,
#  'persons story': 1488,
#  'is your': 944,
#  'meet you': 1205,
#  'at pm': 134,
#  'hi its': 743,
#  'its kate': 991,
#  'how is': 782,
#  'hope can': 767,
#  'can see': 324,
#  'you tomorrow': 2457,
#  'but have': 231,
#  'back if': 159,
#  'if can': 804,
#  'sent you': 1652,
#  'gt bucks': 634,
#  'now so': 1364,
#  'lt decimal': 1136,
#  'decimal gt': 426,
#  'balance is': 163,
#  'rs lt': 1597,
#  'like dat': 1082,
#  'give us': 594,
#  'so get': 1713,
#  'get ready': 575,
#  'what up': 2250,
#  'you had': 2411,
#  'home so': 765,
#  'so we': 1731,
#  'we can': 2197,
#  'how noe': 788,
#  'its good': 989,
#  'to take': 2021,
#  'you should': 2445,
#  'think you': 1930,
#  'you can': 2386,
#  'but if': 233,
#  'can help': 317,
#  'but when': 250,
#  'you do': 2394,
#  'sure you': 1800,
#  'ok no': 1404,
#  'no prob': 1321,
#  'there is': 1918,
#  'give it': 592,
#  'it to': 979,
#  'of course': 1378,
#  'txt nokia': 2061,
#  'nokia to': 1330,
#  'from only': 557,
#  'talk to': 1808,
#  'is ur': 939,
#  'life is': 1079,
#  'good morning': 618,
#  'now only': 1359,
#  'at first': 126,
#  'are going': 95,
#  'in work': 880,
#  'can find': 311,
#  'or even': 1443,
#  'to join': 1990,
#  'just reply': 1018,
#  'reply with': 1584,
#  'ill be': 827,
#  'bus stop': 225,
#  'you when': 2465,
#  'the person': 1886,
#  'so dont': 1710,
#  'with ur': 2335,
#  'ur friends': 2095,
#  'have secret': 691,
#  'secret admirer': 1614,
#  'admirer who': 12,
#  'is looking': 915,
#  'looking make': 1123,
#  'make contact': 1146,
#  'contact with': 394,
#  'with find': 2325,
#  'out who': 1474,
#  'who they': 2285,
#  'they reveal': 1922,
#  'reveal who': 1589,
#  'who thinks': 2286,
#  'thinks ur': 1932,
#  'ur so': 2106,
#  'so special': 1726,
#  'special call': 1764,
#  'call on': 283,
#  'no just': 1315,
#  'on that': 1421,
#  'that was': 1846,
#  'meant to': 1200,
#  'now but': 1352,
#  'but really': 243,
#  'have the': 694,
#  'call him': 274,
#  'him now': 747,
#  'oh ok': 1399,
#  'then ll': 1909,
#  'have it': 685,
#  'by the': 260,
#  'the time': 1893,
#  'wake up': 2157,
#  'are very': 102,
#  'good night': 619,
#  'congratulations ur': 391,
#  'awarded of': 149,
#  'of cd': 1377,
#  'vouchers or': 2146,
#  'or gift': 1444,
#  'gift guaranteed': 588,
#  'draw txt': 473,
#  'txt music': 2060,
#  'music to': 1255,
#  'to tncs': 2027,
#  'tncs www': 1954,
#  'www ldew': 2359,
#  'ldew com': 1064,
#  'com win': 373,
#  'win ppmx': 2315,
#  'ppmx age': 1524,
#  'bcums angry': 164,
#  'take it': 1805,
#  'seriously coz': 1653,
#  'being angry': 199,
#  'is most': 920,
#  'way of': 2192,
#  'showing deep': 1682,
#  'kettoda manda': 1028,
#  'have nice': 688,
#  'day da': 419,
#  'the other': 1885,
#  'when it': 2263,
#  'you may': 2427,
#  'may have': 1162,
#  'get your': 586,
#  'lemme know': 1072,
#  'before you': 197,
#  'get back': 566,
#  'our offer': 1463,
#  'video handset': 2137,
#  'handset anytime': 661,
#  'mins unlimited': 1216,
#  'unlimited text': 2073,
#  'camcorder reply': 296,
#  'reply or': 1581,
#  'or call': 1441,
#  'when are': 2257,
#  'my own': 1279,
#  'cos my': 398,
#  'me if': 1174,
#  'if ur': 822,
#  'see me': 1620,
#  'to unsubscribe': 2029,
#  'text stop': 1821,
#  'why you': 2290,
#  'hold of': 755,
#  'stop txt': 1795,
#  'had to': 656,
#  'to download': 1972,
#  'get the': 578,
#  'week and': 2220,
#  'this message': 1934,
#  'message is': 1207,
#  'is free': 905,
#  'come to': 382,
#  'has ended': 673,
#  'for another': 508,
#  'another day': 82,
#  'has come': 672,
#  'come in': 379,
#  'in special': 871,
#  'special way': 1767,
#  'way may': 2191,
#  'may you': 1164,
#  'you smile': 2446,
#  'smile like': 1697,
#  'like the': 1085,
#  'rays and': 1551,
#  'leaves your': 1071,
#  'the blue': 1858,
#  'blue blue': 213,
#  'blue bay': 212,
#  'now send': 1363,
#  'send hmv': 1636,
#  'hmv to': 754,
#  'more info': 1241,
#  'as well': 115,
#  'well take': 2233,
#  'not coming': 1338,
#  'in bit': 840,
#  'sent it': 1648,
#  'it so': 975,
#  'so what': 1732,
#  'type of': 2068,
#  'if the': 820,
#  'is so': 929,
#  'how far': 780,
#  'last night': 1051,
#  'and ll': 62,
#  'hi baby': 739,
#  'with my': 2330,
#  'call in': 277,
#  'in and': 837,
#  'me on': 1183,
#  'me not': 1181,
#  'because love': 187,
#  'love my': 1131,
#  'life but': 1078,
#  'love the': 1132,
#  'in my': 859,
#  'the world': 1901,
#  'things are': 1925,
#  'hey you': 736,
#  'name to': 1294,
#  'you this': 2455,
#  'the message': 1872,
#  'claim your': 358,
#  'camera phone': 302,
#  'you go': 2405,
#  'would be': 2354,
#  'but in': 234,
#  'cant pick': 332,
#  'pick the': 1495,
#  'the phone': 1887,
#  'phone right': 1491,
#  'right now': 1590,
#  'now pls': 1361,
#  'pls send': 1511,
#  'send message': 1639,
#  'believe it': 201,
#  'it that': 978,
#  'that time': 1844,
#  'the last': 1868,
#  'time we': 1951,
#  'we got': 2203,
#  'that is': 1834,
#  'is really': 928,
#  'in your': 882,
#  'go out': 604,
#  'out for': 1466,
#  'should be': 1675,
#  'ask if': 119,
#  'selection of': 1631,
#  'keep your': 1027,
#  'are the': 100,
#  'this week': 1941,
#  'our weekly': 1464,
#  'to now': 2003,
#  'he says': 710,
#  'says he': 1612,
#  'he ll': 707,
#  'll give': 1101,
#  'call when': 290,
#  'before the': 196,
#  'the week': 1898,
#  'know the': 1038,
#  'rest of': 1587,
#  'you made': 2425,
#  'my day': 1263,
#  'great day': 632,
#  'have no': 689,
#  'mobile mths': 1232,
#  'colour camera': 370,
#  'camera mobile': 301,
#  'mobile for': 1230,
#  'to you': 2037,
#  'you too': 2458,
#  'babe love': 154,
#  'love ya': 1134,
#  'that would': 1851,
#  'we ll': 2207,
#  'll be': 1095,
#  'be at': 167,
#  'get in': 570,
#  'no problem': 1322,
#  'say that': 1610,
#  'well you': 2234,
#  'reading the': 1565,
#  'read it': 1564,
#  'it in': 961,
#  'or something': 1450,
#  'for only': 523,
#  'per minute': 1483,
#  'you might': 2428,
#  'might have': 1210,
#  'have had': 684,
#  'my phone': 1282,
#  ...}
