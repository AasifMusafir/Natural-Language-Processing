# %%
from nltk.tokenize import sent_tokenize

corpus="Hello! This is Asif.I like to learn about Machine Learning and Deep Learning. I am also working as a Jr.Deep Learning Engineer."

print(corpus)
# Out:
# Hello! This is Asif.I like to learn about Machine Learning and Deep Learning. I am also working as a Jr.Deep Learning Engineer.

# %%
sent_tokenize(corpus)
# Out:
# ['Hello!',
#  'This is Asif.I like to learn about Machine Learning and Deep Learning.',
#  'I am also working as a Jr.Deep Learning Engineer.']

# %%
documents=sent_tokenize(corpus)

for sentence  in documents:
    print(sentence)
# Out:
# Hello!
# This is Asif.I like to learn about Machine Learning and Deep Learning.
# I am also working as a Jr.Deep Learning Engineer.

# %%
#Tokenization
#Paragraph->words
#sentence->words

from nltk.tokenize import word_tokenize

word_tokenize(corpus)
# Out:
# ['Hello',
#  '!',
#  'This',
#  'is',
#  'Asif.I',
#  'like',
#  'to',
#  'learn',
#  'about',
#  'Machine',
#  'Learning',
#  'and',
#  'Deep',
#  'Learning',
#  '.',
#  'I',
#  'am',
#  'also',
#  'working',
#  'as',
#  'a',
#  'Jr.Deep',
#  'Learning',
#  'Engineer',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', '!']
# ['This', 'is', 'Asif.I', 'like', 'to', 'learn', 'about', 'Machine', 'Learning', 'and', 'Deep', 'Learning', '.']
# ['I', 'am', 'also', 'working', 'as', 'a', 'Jr.Deep', 'Learning', 'Engineer', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  '!',
#  'This',
#  'is',
#  'Asif',
#  '.',
#  'I',
#  'like',
#  'to',
#  'learn',
#  'about',
#  'Machine',
#  'Learning',
#  'and',
#  'Deep',
#  'Learning',
#  '.',
#  'I',
#  'am',
#  'also',
#  'working',
#  'as',
#  'a',
#  'Jr',
#  '.',
#  'Deep',
#  'Learning',
#  'Engineer',
#  '.']

# %%
from nltk import TreebankWordTokenizer

tokenizer=TreebankWordTokenizer()

tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  '!',
#  'This',
#  'is',
#  'Asif.I',
#  'like',
#  'to',
#  'learn',
#  'about',
#  'Machine',
#  'Learning',
#  'and',
#  'Deep',
#  'Learning.',
#  'I',
#  'am',
#  'also',
#  'working',
#  'as',
#  'a',
#  'Jr.Deep',
#  'Learning',
#  'Engineer',
#  '.']
